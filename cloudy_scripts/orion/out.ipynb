# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('pnpn.con', sep='\t')
wl = data['#Cont  nu']
flux = data['total']
data
# Out:
#          #Cont  nu      incident  trans       DiffOut     net trans  reflc  \
# 0     2.992930e+07  1.711000e+12    0.0  3.105000e+26  3.105000e+26    0.0
# 1     2.982970e+07  1.728000e+12    0.0  3.140000e+26  3.140000e+26    0.0
# 2     2.973040e+07  1.745000e+12    0.0  3.174000e+26  3.174000e+26    0.0
# 3     2.963150e+07  1.763000e+12    0.0  3.210000e+26  3.210000e+26    0.0
# 4     2.953290e+07  1.781000e+12    0.0  3.245000e+26  3.245000e+26    0.0
# ...            ...           ...    ...           ...           ...    ...
# 9239  1.461500e-08  0.000000e+00    0.0  0.000000e+00  0.000000e+00    0.0
# 9240  1.418420e-08  0.000000e+00    0.0  0.000000e+00  0.000000e+00    0.0
# 9241  1.376600e-08  0.000000e+00    0.0  0.000000e+00  0.000000e+00    0.0
# 9242  1.336010e-08  0.000000e+00    0.0  0.000000e+00  0.000000e+00    0.0
# 9243  1.296620e-08  0.000000e+00    0.0  0.000000e+00  0.000000e+00    0.0
#
#              total  reflin  outlin lineID  cont  nLine
# ...

# %%
plt.plot(wl, flux)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Wavelength (in microns)')
plt.ylabel('$\\nu L_\\nu$ (erg/s)')
plt.xlim(1e-3, 1e7)
# Out:
# (0.001, 10000000.0)

# %%
data1 = pd.read_csv('pnpn.ovr', sep='\t')
data1
# Out:
#            #depth       Te          Htot      hden     eden        2H_2/H  \
# 0    8.639050e+09  10529.0  4.090000e-14  100000.0  96425.0  2.775400e-10
# 1    5.183430e+10  10525.0  4.067000e-14  100000.0  96014.0  2.761900e-10
# 2    2.246150e+11  10515.0  4.041000e-14  100000.0  95972.0  2.758800e-10
# 3    9.157390e+11  10492.0  3.976000e-14  100000.0  96030.0  2.767600e-10
# 4    2.187410e+12  10414.0  3.781000e-14  100000.0  96567.0  2.680800e-10
# ..            ...      ...           ...       ...      ...           ...
# 146  4.235370e+14   4230.8  6.534000e-17  100000.0   1041.9  6.524400e-06
# 147  4.252090e+14   4169.5  6.450000e-17  100000.0   1033.5  7.276700e-06
# 148  4.268250e+14   4108.7  6.369000e-17  100000.0   1025.4  8.117300e-06
# 149  4.283870e+14   4048.3  6.293000e-17  100000.0   1017.7  9.055100e-06
# 150  4.298950e+14   3988.3  6.221000e-17  100000.0   1010.3  1.010000e-05
#
#           HI       HII      HeI      HeII  ...       O1        O2  \
# ...

# %%
plt.plot(data1['#depth'], data1['Te'])
plt.yscale('log')
plt.xlabel('Radius (cm)')
plt.ylabel('log$T_e$ (K)')
# Out:
# Text(0, 0.5, 'log$T_e$ (K)')
